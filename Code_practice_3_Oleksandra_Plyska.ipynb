# %% [markdown]
# # Question 1

# %%
import pandas as pd
data = {"BRA": [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
       'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
       'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
       'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

# %%
#a) We imported a package for managing data called "pandas" under the abbreviation "pd". It means that whenever we 
#need to get data from pandas, we would use pd.

# %%
type(data)

#b) data has a type dict
# Out:
# dict

# %%
#c) because it creates a dataframe out of the pandas data package

# %%
type(weo)

#d)the type of weo is DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
weo.shape

#e) 4 columns and 7 rows
# Out:
# (7, 4)

# %%
weo.dtypes
#f) the dtype of variables are floats and integer, while for columns it's an object. It says the dtype is an object because
#the columns are strings and cannot be converted to numbers.  Dtype is the type of values within each colmn.
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %%
#g) this pulls out the column Year, which has the type 'series'. 
weo['Year']
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64

# %%
type(weo['Year'])
# Out:
# pandas.core.series.Series

# %%
weo[["Year"]]

#this pulls out a dataframe for the column Year with the row number and a column name
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %%
type(weo[["Year"]])

#the type is DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
weo[[3]] 
#this kicks back an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-d430695cfe82> in <module>()
# ----> 1 weo[[3]]
#       2 #this kicks back an error
#
# /Users/oleksandra/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /Users/oleksandra/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
# ...

# %%
# to pull out the third columns we would have to use this:
weo.columns[[3]]
# Out:
# Index(['Year'], dtype='object')

# %%
type(weo.columns[[3]])
#the type is index
# Out:
# pandas.core.indexes.base.Index

# %%
#h)

weo["Year"].astype(float)
# Out:
# 0    2008.0
# 1    2009.0
# 2    2010.0
# 3    2011.0
# 4    2012.0
# 5    2013.0
# 6    2014.0
# Name: Year, dtype: float64

# %%
#i)This pulled out the last 3 rows from the dataset. The type of the object is DataFrame, and it created a dataframe
#with 3 last rows. 

t = weo.tail(3)
t
# Out:
#      BRA    JPN    USA  Year
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %%
type(t)
# Out:
# pandas.core.frame.DataFrame

# %%
#j) New dataframe with first 4 rows:
Newdataframe = weo.head(4)
Newdataframe
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011

# %%
#k) The type is series
type(weo['BRA'])
# Out:
# pandas.core.series.Series

# %%
#l) A new variable equal to Brazil's GDP to Japan's
weo['NEW'] = weo['BRA']/weo['JPN']

# %%
weo
# Out:
#      BRA    JPN    USA  Year       NEW
# 0  13.37  33.43  48.30  2008  0.399940
# 1  13.30  31.83  46.91  2009  0.417845
# 2  14.34  33.71  48.31  2010  0.425393
# 3  15.07  34.29  49.72  2011  0.439487
# 4  15.46  35.60  51.41  2012  0.434270
# 5  15.98  36.79  52.94  2013  0.434357
# 6  16.10  37.39  54.60  2014  0.430596

# %%
#m) Dropped the new variable 'NEW'
weo.drop(['NEW'], axis=1, inplace = True)

# %%
weo
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %%
#n) columns labels
weo.columns.tolist()
# Out:
# ['BRA', 'JPN', 'USA', 'Year']

# %%
# rows
weo.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
#o) setting the index to Year variable
weo.set_index("Year")
# Out:
#         BRA    JPN    USA
# Year
# 2008  13.37  33.43  48.30
# 2009  13.30  31.83  46.91
# 2010  14.34  33.71  48.31
# 2011  15.07  34.29  49.72
# 2012  15.46  35.60  51.41
# 2013  15.98  36.79  52.94
# 2014  16.10  37.39  54.60

# %%
#p) Changing the names of the variables

weo.rename(columns = {"BRA": "Brazil", "JPN": "Japan", "USA": "United States"})
# Out:
#    Brazil  Japan  United States  Year
# 0   13.37  33.43          48.30  2008
# 1   13.30  31.83          46.91  2009
# 2   14.34  33.71          48.31  2010
# 3   15.07  34.29          49.72  2011
# 4   15.46  35.60          51.41  2012
# 5   15.98  36.79          52.94  2013
# 6   16.10  37.39          54.60  2014

# %%
#q) Exporting to excel

ex = weo.to_excel
ex
# Out:
# <bound method DataFrame.to_excel of      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014>

# %%
#r) Calculating the mean of each country. The means are shown below.

weo.mean()
# Out:
# BRA       14.802857
# JPN       34.720000
# USA       50.312857
# Year    2011.000000
# dtype: float64

# %%
#s) Created  means across countries for each year.

weo[['BRA', 'JPN', 'USA']].mean(axis = 1)
# Out:
# 0    31.700000
# 1    30.680000
# 2    32.120000
# 3    33.026667
# 4    34.156667
# 5    35.236667
# 6    36.030000
# dtype: float64

# %%
#t) Plotted the Dataframe
weo[['BRA', 'JPN', 'USA']].plot(kind = "barh")
plt.show()

# %%
#u) Changing colors
weo[['BRA', 'JPN', 'USA']].plot(kind = "barh", color = ["green", "red", "blue"])

plt.show()

# %%
#v)
weo.plot(color=['green', 'red', 'blue'], logy = True)
plt.show()

# %%
#w) Plotting Brazil on its own

weo[['BRA']].plot(kind = "barh")
plt.show()

# %% [markdown]
# # Question 2

# %%
url  = 'https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv'
pd.read_csv(url)
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %%
#a)

ep = pd.read_csv(url)   
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %%
#b) 
ep.describe()
# Out:
#                   TimeStamp Why have you enrolled in this course?    \
# count                    85                                      85
# unique                   85                                       9
# top     2016-09-21 13:22:54                  To help with my career
# freq                      1                                      60
#
#        What program are you enrolled in?  \
# count                                 85
# unique                                11
# top                                  MBA
# freq                                  41
#
#        How much programming experience have you had?  \
# count                                             85
# unique                                             4
# top                                             None
# freq                                              50
#
#        How much experience with probability and statistics have you had?  \
# count                                                  85
# ...

# %%
#The variables are questions, which are strings. There are the variables:
list(ep.columns)
# Out:
# ['TimeStamp',
#  'Why have you enrolled in this course?  ',
#  'What program are you enrolled in?',
#  'How much programming experience have you had?',
#  'How much experience with probability and statistics have you had?',
#  'What is your expected major or concentration? ',
#  'What career path most interests you? ',
#  'Do you use social media for information purposes?  Check all that apply.',
#  'What kinds of data most interest you?  List any that cross your mind.  ',
#  'If we have time -- and we may not -- what special topics would interest you?  Check all that apply.']

# %%
#There are 85 rows of responses, which are written words, not numbers
ep.index
# Out:
# RangeIndex(start=0, stop=85, step=1)

# %%
#c) 

ep.dtypes
#the variables are ojects, because they are not  numerial values.
# Out:
# TS                                   object
# Why you enrolled                     object
# Programs enrolled in                 object
# Programming experience               object
# Probability&statistics experience    object
# Expected major                       object
# Career path                          object
# Social Media                         object
# Kinds of data                        object
# Special topics                       object
# dtype: object

# %%
#d) Changing names to something shorter
ep.columns = ["TS", "Why you enrolled", "Programs enrolled in", "Programming experience", "Probability&statistics experience", "Expected major", "Career path", "Social Media", "Kinds of data", "Special topics"]

# %%
ep
# Out:
#                      TS                                   Why you enrolled  \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %%
#e)
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# i am living in Santiago de Chile                      1
# Wanted to try something completely different          1
# To finish my major                                    1
# I like a challenge                                    1
# Recommended by a professor.                           1
# I code/build websites in my spare time as a hobby     1
# Name: Why you enrolled, dtype: int64

# %%
ep[list(ep)[1]]
#this one is making a list of out all the responses from the column 1(Why you enrolled in this course?)
# Out:
# 0                                To help with my career
# 1                                    I heard it was fun
# 2                                    I like a challenge
# 3                                    I heard it was fun
# 4                                    I heard it was fun
# 5                                    I heard it was fun
# 6                                To help with my career
# 7                                To help with my career
# 8                           I lost my mind for a minute
# 9                                    I heard it was fun
# 10                               To help with my career
# 11                               To help with my career
# 12                               To help with my career
# 13                                   I heard it was fun
# 14    I code/build websites in my spare time as a hobby
# 15                               To help with my career
# 16                          I lost my mind for a minute
# ...

# %%
ep[list(ep)[1]].value_counts()
# this one is counting the number of times an identical response showed up in a list, and then counts the values. 
#thus, people replied "to help with my career" 60 times, "I heard it was fun" - 14, etc
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# i am living in Santiago de Chile                      1
# Wanted to try something completely different          1
# To finish my major                                    1
# I like a challenge                                    1
# Recommended by a professor.                           1
# I code/build websites in my spare time as a hobby     1
# Name: Why you enrolled, dtype: int64

# %% [markdown]
# # Question 3

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2

# %%
#a)
df538 = pd.read_csv(url)
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df538.shape
#dimensions: it has 21 columns and 173 rows
# Out:
# (173, 21)

# %%
#b) reads only first 10 lines
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %%
#c) Extracting the variables 2, 4, 15, 16, 17
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2

df_new = pd.read_csv(url,
                     usecols=[2,4,15,16,17]
                     )

df_new
# Out:
#                                              Major      Men  Median  P25th  \
# 0                            PETROLEUM ENGINEERING   2057.0  110000  95000
# 1                   MINING AND MINERAL ENGINEERING    679.0   75000  55000
# 2                        METALLURGICAL ENGINEERING    725.0   73000  50000
# 3        NAVAL ARCHITECTURE AND MARINE ENGINEERING   1123.0   70000  43000
# 4                             CHEMICAL ENGINEERING  21239.0   65000  50000
# 5                              NUCLEAR ENGINEERING   2200.0   65000  50000
# 6                                ACTUARIAL SCIENCE   2110.0   62000  53000
# 7                       ASTRONOMY AND ASTROPHYSICS    832.0   62000  31500
# 8                           MECHANICAL ENGINEERING  80320.0   60000  48000
# 9                           ELECTRICAL ENGINEERING  65511.0   60000  45000
# 10                            COMPUTER ENGINEERING  33258.0   60000  45000
# ...

# %%
# the names of the variables
df538.columns[[2, 4, 15, 16, 17]]
# Out:
# Index(['Total', 'Women', 'P25th', 'P75th', 'College_jobs'], dtype='object')

# %%
#The variables represent the columns with  integer or float values as responses.
df538.dtypes
# Out:
# Rank                      int64
# Major_code                int64
# Total                   float64
# Men                     float64
# Women                   float64
# Major_category           object
# ShareWomen              float64
# Sample_size               int64
# Employed                  int64
# Full_time                 int64
# Part_time                 int64
# Full_time_year_round      int64
# Unemployed                int64
# Unemployment_rate       float64
# Median                    int64
# P25th                     int64
# P75th                     int64
# College_jobs              int64
# Non_college_jobs          int64
# Low_wage_jobs             int64
# dtype: object

# %%
#d) Setting the index to Major
df538.set_index("Major", inplace = True)
df538
# Out:
#                                                Rank  Major_code     Total  \
# Major
# PETROLEUM ENGINEERING                             1        2419    2339.0
# MINING AND MINERAL ENGINEERING                    2        2416     756.0
# METALLURGICAL ENGINEERING                         3        2415     856.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         4        2417    1258.0
# CHEMICAL ENGINEERING                              5        2405   32260.0
# NUCLEAR ENGINEERING                               6        2418    2573.0
# ACTUARIAL SCIENCE                                 7        6202    3777.0
# ASTRONOMY AND ASTROPHYSICS                        8        5001    1792.0
# MECHANICAL ENGINEERING                            9        2414   91227.0
# ELECTRICAL ENGINEERING                           10        2408   81527.0
# COMPUTER ENGINEERING                             11        2407   41542.0
# AEROSPACE ENGINEERING                            12        2401   15058.0
# ...

# %%
#e) Sorting values by Total
df538.sort_values('Total')
# Out:
#                                                     Rank  Major_code  \
# Major
# MILITARY TECHNOLOGIES                                 74        3801
# MATHEMATICS AND COMPUTER SCIENCE                      53        4005
# SOIL SCIENCE                                         113        1106
# GEOLOGICAL AND GEOPHYSICAL ENGINEERING                34        2411
# MINING AND MINERAL ENGINEERING                         2        2416
# EDUCATIONAL ADMINISTRATION AND SUPERVISION           121        2301
# SCHOOL STUDENT COUNSELING                             56        2303
# METALLURGICAL ENGINEERING                              3        2415
# LIBRARY SCIENCE                                      173        3501
# COURT REPORTING                                       20        3201
# NAVAL ARCHITECTURE AND MARINE ENGINEERING              4        2417
# BOTANY                                                84        3602
# ...

# %%
#f)
df538.sort_values('Total').tail(10)
# Out:
#      Rank  Major_code                                   Major     Total  \
# 137   138        3301         ENGLISH LANGUAGE AND LITERATURE  194673.0
# 40     41        6201                              ACCOUNTING  198633.0
# 77     78        6206        MARKETING AND MARKETING RESEARCH  205211.0
# 34     35        6107                                 NURSING  209394.0
# 93     94        1901                          COMMUNICATIONS  213996.0
# 57     58        6200                        GENERAL BUSINESS  234590.0
# 123   124        3600                                 BIOLOGY  280709.0
# 76     77        6203  BUSINESS MANAGEMENT AND ADMINISTRATION  329927.0
# 145   146        5200                              PSYCHOLOGY  393735.0
# 21     22        1104                            FOOD SCIENCE       NaN
#
#           Men     Women                   Major_category  ShareWomen  \
# 137   58227.0  136446.0        Humanities & Liberal Arts    0.700898
# ...

# %%
#g)

df_new = df538.sort_values('Total').tail(10)

# %%
df_new.sort_values('Median')
# Out:
#                                         Rank  Major_code     Total       Men  \
# Major
# PSYCHOLOGY                               146        5200  393735.0   86648.0
# ENGLISH LANGUAGE AND LITERATURE          138        3301  194673.0   58227.0
# BIOLOGY                                  124        3600  280709.0  111762.0
# COMMUNICATIONS                            94        1901  213996.0   70619.0
# MARKETING AND MARKETING RESEARCH          78        6206  205211.0   78857.0
# BUSINESS MANAGEMENT AND ADMINISTRATION    77        6203  329927.0  173809.0
# GENERAL BUSINESS                          58        6200  234590.0  132238.0
# ACCOUNTING                                41        6201  198633.0   94519.0
# NURSING                                   35        6107  209394.0   21773.0
# FOOD SCIENCE                              22        1104       NaN       NaN
#
#                                            Women  \
# Major
# PSYCHOLOGY                              307087.0
# ...

# %%
df_new.sort_values('Median').Median.plot(kind = 'barh')

plt.show()
#a bar chart sorted by median salary

# %%
df_new.sort_values('P25th').P25th.plot(kind = 'barh')

plt.show()
